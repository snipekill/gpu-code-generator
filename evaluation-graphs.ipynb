# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# set width of bar
barWidth = 0.25
fig = plt.subplots(figsize =(12, 8))

####### Plots for MAC

# set height of bar
tetra = [3.8400, 3.4560, 4.0960, 7.296, 7.36, 7.263]
aws = [4.5120, 4.9280, 6.1120, 10.7, 10.9, 11]

# Set position of bar on X axis
bar1 = np.arange(len(tetra))
bar2 = [x + barWidth for x in bar1]

# Make the plot
plt.bar(bar1, tetra, color ='b', width = barWidth,
		edgecolor ='grey', label ='Titan V')
plt.bar(bar2, aws, color ='g', width = barWidth,
		edgecolor ='grey', label ='Tesla M60')

# Adding Xticks
plt.xlabel('Input Size', fontweight ='bold', fontsize = 15)
plt.ylabel('Execution Time (us)', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(tetra))],
		['256', '512', '1024', '2048', '4096', '8192'])

plt.legend()
plt.show()

# %%
####### Plots for GEMM

# set height of bar
fig = plt.subplots(figsize =(12, 8))
tetra = [4.7670, 7.0720, 10.112, 24.608,115.78, 880.44]
tetra_cublas = [81,87,73,74,78,336]

# Set position of bar on X axis
bar1 = np.arange(len(tetra))
bar2 = [x + barWidth for x in bar1]

# Make the plot
plt.bar(bar1, tetra, color ='b', width = barWidth,
		edgecolor ='grey', label ='Automated Code')
plt.bar(bar2, tetra_cublas, color ='g', width = barWidth,
		edgecolor ='grey', label ='CuBlas')

# Adding Xticks
plt.xlabel('Input Size (Square Matrices)', fontweight ='bold', fontsize = 15)
plt.ylabel('Execution Time (us)', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(tetra))],
		['32', '64', '128', '256', '512', '1024'])

plt.legend()
plt.show()

# %%
####### Plots for GEMM

# set height of bar
fig = plt.subplots(figsize =(12, 8))
aws = [6.4320, 9.4400, 15.872, 133.25,728.68, 5540.5]
aws_cublas = [85, 83, 96, 100,181,956]

# Set position of bar on X axis
bar1 = np.arange(len(tetra))
bar2 = [x + barWidth for x in bar1]

# Make the plot
plt.bar(bar1, aws, color ='b', width = barWidth,
		edgecolor ='grey', label ='Automated Code')
plt.bar(bar2, aws_cublas, color ='g', width = barWidth,
		edgecolor ='grey', label ='CuBlas')

# Adding Xticks
plt.xlabel('Input Size (Square Matrices)', fontweight ='bold', fontsize = 15)
plt.ylabel('Execution Time (us)', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(tetra))],
		['32', '64', '128', '256', '512', '1024'])

plt.legend()
plt.show()

# %%
# ####### Plots for 3D

# set height of bar
fig = plt.subplots(figsize =(12, 8))
tetra_14 = [812, 1245, 2883, 4768]
cudnn_14 = [529, 628,1036,1865]
tetra_224 = [2.53, 7.04, 11.98, 29.67]
cudnn_224 = [2.02, 4.14,6.63,13.38]


# Set position of bar on X axis
bar1 = np.arange(len(tetra_14))
bar2 = [x + barWidth for x in bar1]
bar3 = [x + barWidth for x in bar2]

# Make the plot
plt.bar(bar1, tetra_14, color ='b', width = barWidth,
		edgecolor ='grey', label ='Automated Code')
plt.bar(bar2, cudnn_14, color ='r', width = barWidth,
		edgecolor ='grey', label ='cuDNN')     

# Adding Xticks
plt.xlabel('Batch Size', fontweight ='bold', fontsize = 15)
plt.ylabel('Execution Time (us)', fontweight ='bold', fontsize = 15)
####### Update the x-ticks accordingly
plt.xticks([r + barWidth for r in range(len(tetra_14))],
		['2', '4', '8', '16'])

plt.legend()
plt.show()

# %%
# ####### Plots for 3D

# set height of bar
fig = plt.subplots(figsize =(12, 8))
tetra_14 = [812, 1245, 2883, 4768]
cudnn_14 = [529, 628,1036,1865]
tetra_224 = [2.53, 7.04, 11.98, 29.67]
cudnn_224 = [2.02, 4.14,6.63,13.38]


# Set position of bar on X axis
bar1 = np.arange(len(tetra_224))
bar2 = [x + barWidth for x in bar1]
bar3 = [x + barWidth for x in bar2]

# Make the plot
plt.bar(bar1, tetra_224, color ='b', width = barWidth,
		edgecolor ='grey', label ='Automated Code')
plt.bar(bar2, cudnn_224, color ='r', width = barWidth,
		edgecolor ='grey', label ='cuDNN')     

# Adding Xticks
plt.xlabel('Batch Size', fontweight ='bold', fontsize = 15)
plt.ylabel('Execution Time (ms)', fontweight ='bold', fontsize = 15)
####### Update the x-ticks accordingly
plt.xticks([r + barWidth for r in range(len(tetra_224))],
		['2', '4', '8', '16'])

plt.legend()
plt.show()
